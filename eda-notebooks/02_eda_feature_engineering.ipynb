# %% [markdown]
# # Dataset Information
#
# ### Description
# This notebook focuses on the EDA process of the three datasets: `driver_ratings`, `feedback`, and `telemetry` (all in *.csv* format). The datasets describe delivery-related data for an anonymous last-mile logistics company.
# The datasets provide information such as per delivery customer ratings, feedback descriptions, and driver handling information.

# %% [markdown]
# ### Data Dictionary
# ##### driver_ratings.csv
# <div style="display: flex; justify-content: center; margin: 20px 0;">
#
# <table style="
#     border-collapse: collapse;
#     border: 2px solid lightgray;
#     width: 60%;
#     font-size: 1rem;
# ">
#
# <thead>
# <tr style="background-color: whitesmoke;">
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Column</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Type</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Description</th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>trip_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery trip instance.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>driver_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery driver.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>rating</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Customer rating [1.0,5.0] for a delivery.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>late_delivery_flag</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">boolean (binary)</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Denotes whether a delivery was late or on time.</td>
# </tr>
#
# </tbody>
#
# </table>
#
# </div>

# %% [markdown]
# ##### telemetry.csv
# <div style="display: flex; justify-content: center; margin: 20px 0;">
#
# <table style="
#     border-collapse: collapse;
#     border: 2px solid lightgray;
#     width: 60%;
#     font-size: 1rem;
# ">
#
# <thead>
# <tr style="background-color: whitesmoke;">
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Column</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Type</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Description</th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>trip_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery trip instance.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>driver_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery driver.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>timestamp</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">datetime</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Date and time of a delivery.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>max_speed_kmh</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Delivery vehicle's maximum speed recorded by telemetry hardware.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>avg_speed_kmh</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Delivery vehicle's average speed recorded by telemetry hardware.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>throttle_pct</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Average throttle or gas pedal position for the duration of the trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>speed_kmh</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Delivery vehicle's average speed recorded by telemetry hardware.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>max_steering_rate_deg_per_s</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Maximum recorded steering rate (degrees per second) durin the trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_fwd_x_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest forward longitudinal acceleration experienced by the vehicle (measured in G's).</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_rear_x_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest decceleration force experienced by the vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_right_y_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest rightward lateral g-force experienced by the vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_left_y_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest leftward lateral g-force experienced by the vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_up_z_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest upward vertical g-force experienced by the vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>peak_down_z_g</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Highest downward vertical g-force experiencned by the vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>overspeed_count</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Number of times a vehicle exceeded the speed limit during a trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>hard_brake_count</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Number of hard braking instances detected during a trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>swerving_count</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Number of swerving instances detected during a trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>handling_risk_score</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">A metric that represents how likely packages were at risk of damage due to a driver's handling during a trip. Range is a percentage (0-100%)</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>event_code</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">categorical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Denotes overall vehicle behavior during the trip according to telemetry data.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>distance_tr_km</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Distance travelled in kilometers by a vehicle during a trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>trip_duration_sec</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">numerical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Total trip duration recorded in seconds.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>traffic_condition</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">categorical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">The overall traffic condition during the trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>weather_condition</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">categorical</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">The overall weather condition at the time of the trip.</td>
# </tr>
#
# </tbody>
#
# </table>
#
# </div>

# %% [markdown]
# ##### feedback.csv
# <div style="display: flex; justify-content: center; margin: 20px 0;">
# <table style="
#     border-collapse: collapse;
#     border: 2px solid lightgray;
#     width: 60%;
#     font-size: 1rem;
# ">
#
# <thead>
# <tr style="background-color: whitesmoke;">
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Column</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Type</th>
#     <th style="border: 1px solid lightgray; padding: 10px; text-align: center;">Description</th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>trip_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery trip instance.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>driver_id</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">identifier</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Unique identifier for a delivery driver.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>feedback_txt</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">text/string</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Customers' description of their delivery experience.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid lightgray; padding: 8px;"><code>timestamp</code></td>
#     <td style="border: 1px solid lightgray; padding: 8px;">datetime</td>
#     <td style="border: 1px solid lightgray; padding: 8px;">Date and time at which the feedback was submitted.</td>
# </tr>
#
# </tbody>
#
# </table>
#
# </div>

# %% [markdown]
# # Import
#
# ### Needed Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_palette('muted')

# %% [markdown]
# ### Datasets

# %%
ratings = pd.read_csv('../data/driver_ratings.csv')
feedbacks = pd.read_csv('../data/feedbacks.csv')
telemetry = pd.read_csv('../data/telemetry.csv')

# %% [markdown]
# ### Data Validation
#
# ##### Null Value Checks

# %%
for name, df in {'ratings':ratings, 'feedbacks':feedbacks, 'telemetry':telemetry}.items():
    print(f"Nulls found in \'{name}\' dataframe: {df.isna().sum().sum()}")
# Out:
# Nulls found in 'ratings' dataframe: 0
# Nulls found in 'feedbacks' dataframe: 0
# Nulls found in 'telemetry' dataframe: 0

# %% [markdown]
# ##### Data Type Checks

# %%
ratings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67833 entries, 0 to 67832
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_id             67833 non-null  str
#  1   driver_id           67833 non-null  str
#  2   rating              67833 non-null  float64
#  3   late_delivery_flag  67833 non-null  int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 2.1 MB

# %%
feedbacks.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67833 entries, 0 to 67832
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   trip_id       67833 non-null  str
#  1   driver_id     67833 non-null  str
#  2   feedback_txt  67833 non-null  str
#  3   timestamp     67833 non-null  str
# dtypes: str(4)
# memory usage: 2.1 MB

# %%
feedbacks['timestamp'] = pd.to_datetime(feedbacks['timestamp'])

# %%
telemetry.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67833 entries, 0 to 67832
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   trip_id                      67833 non-null  str
#  1   driver_id                    67833 non-null  str
#  2   timestamp                    67833 non-null  str
#  3   max_speed_kmh                67833 non-null  float64
#  4   avg_speed_kmh                67833 non-null  float64
#  5   throttle_pct                 67833 non-null  float64
#  6   max_steering_rate_deg_per_s  67833 non-null  float64
#  7   peak_fwd_x_g                 67833 non-null  float64
#  8   peak_rear_x_g                67833 non-null  float64
#  9   peak_right_y_g               67833 non-null  float64
#  10  peak_left_y_g                67833 non-null  float64
#  11  peak_up_z_g                  67833 non-null  float64
#  12  peak_down_z_g                67833 non-null  float64
# ...

# %% [markdown]
# From the dataframe information, we can cast certain features to a more appropriate type. `timestamp` can be converted to a datetime, and categorical features, such as `event_code`, `traffic_condition`, and `weather_condition`, can be casted to categorical data type (only after checking the cardinality).
#
# `trip_duration_sec` can also converted to minutet measure instead, which is easier tot interpret.

# %%
telemetry['timestamp'] = pd.to_datetime(telemetry['timestamp'])


telemetry['trip_duration_min'] = telemetry['trip_duration_sec'] / 60
telemetry.drop(columns=['trip_duration_sec'], inplace=True)

# %%
categoricals = ['event_code','traffic_condition','weather_condition']

# %% [markdown]
# Checking feature cardinality for the categorical columns. Since they are mostly limited to at most five categories, we can convert them to a categorical data type to save some space.

# %%
for col in categoricals:
    print(f"Unique vals. for col. \'{col}\':")
    print(telemetry[col].unique())
    print()
# Out:
# Unique vals. for col. 'event_code':
# <StringArray>
# ['NONE', 'HARD_BRK', 'SWERV', 'MULTI', 'OVRSPD']
# Length: 5, dtype: str
#
# Unique vals. for col. 'traffic_condition':
# <StringArray>
# ['LIGHT', 'MODERATE', 'HEAVY']
# Length: 3, dtype: str
#
# Unique vals. for col. 'weather_condition':
# <StringArray>
# ['CLR', 'RAIN']
# Length: 2, dtype: str

# %%
# normalizing traffic and weather condition to title case for readability
# event_code was left unmodified (except for data type) for now
telemetry['traffic_condition'] = telemetry['traffic_condition'].str.title()
telemetry['weather_condition'] = telemetry['weather_condition'].str.replace('CLR','Clear')
telemetry['weather_condition'] = telemetry['weather_condition'].str.title()

for col in categoricals:
    telemetry[col] = telemetry[col].astype('category')

telemetry['traffic_condition'] = telemetry['traffic_condition'].cat.reorder_categories(['Light','Moderate','Heavy'], ordered=True)

# %% [markdown]
# Below shows the dataset with updated data types.

# %%
telemetry.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67833 entries, 0 to 67832
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   trip_id                      67833 non-null  str
#  1   driver_id                    67833 non-null  str
#  2   timestamp                    67833 non-null  datetime64[us]
#  3   max_speed_kmh                67833 non-null  float64
#  4   avg_speed_kmh                67833 non-null  float64
#  5   throttle_pct                 67833 non-null  float64
#  6   max_steering_rate_deg_per_s  67833 non-null  float64
#  7   peak_fwd_x_g                 67833 non-null  float64
#  8   peak_rear_x_g                67833 non-null  float64
#  9   peak_right_y_g               67833 non-null  float64
#  10  peak_left_y_g                67833 non-null  float64
#  11  peak_up_z_g                  67833 non-null  float64
#  12  peak_down_z_g                67833 non-null  float64
# ...

# %% [markdown]
# # EXPLORATION

# %% [markdown]
# ##### Distribution Checks
#
# As per usual, data distributions should be checked in order to determine the underlying structure of the data. This allows us to spot data anomalies, choose the appropriate transformations (if any), and avoid making incorrect assumptions/conclusions.
#
# Starting with the ratings table first.

# %%
ratings.head()
# Out:
#        trip_id  driver_id    rating  late_delivery_flag
# 0  TRP-100-001  DRV100395  4.390375                   1
# 1  TRP-100-002  DRV100381  4.015978                   1
# 2  TRP-100-003  DRV100508  3.998266                   0
# 3  TRP-100-004  DRV100293  5.000000                   0
# 4  TRP-100-005  DRV100076  4.452264                   0

# %% [markdown]
# The rating column is the only continuous numerical feature that can be examined in this table. The values can be put plotted using a histogram to reveal how most customers rate the delivery services and a boxplot to show the range of ratings across all deliveries.

# %%
ratings['rating']
# Out:
# 0        4.390375
# 1        4.015978
# 2        3.998266
# 3        5.000000
# 4        4.452264
#            ...
# 67828    4.455894
# 67829    4.629517
# 67830    4.772666
# 67831    4.170441
# 67832    4.511754
# Name: rating, Length: 67833, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 3))

sns.boxplot(
    data=ratings,
    x='rating',
    ax=ax[0]
)

sns.histplot(
    data=ratings,
    x='rating',
    ax=ax[1]
)

plt.tight_layout()
plt.show()

# %% [markdown]
# The ratings appear to be left-skewed with most having values around the higher 4.0s. Notice in the histogram that there is another peak at the 5.0 mark, which shows that there are over 2500 customers who have had very satisfactory delivery experiences. This is also due to the bounds of the rating system, where the scale only goes up to 5.0 inclusive. Moreover, there are about less than around 400 customers who have given mid to low ratings with the lowest rating recorded being around 2.0. Overall, these plots show that customers are generally satisfied with the delivery services and only a few have had unpleasant experiences.

# %% [markdown]
# The feedbacks dataset will be checked during the NLP phase, and thus will be skipped for now.

# %%
feedbacks.head(3)
# Out:
#        trip_id  driver_id                                       feedback_txt  \
# 0  TRP-100-001  DRV100395  The package arrived within the expected window...
# 1  TRP-100-002  DRV100381  The package was clean and presentable, and the...
# 2  TRP-100-003  DRV100508  The delivery arrived on time, but the contents...
#
#             timestamp
# 0 2026-05-19 13:05:21
# 1 2026-04-21 16:40:06
# 2 2026-03-07 09:03:45

# %% [markdown]
# Finally, the telemetry dataset.

# %%
telemetry.head(2)
# Out:
#        trip_id  driver_id           timestamp  max_speed_kmh  avg_speed_kmh  \
# 0  TRP-100-001  DRV100395 2026-05-19 13:05:21         27.382         20.275
# 1  TRP-100-002  DRV100381 2026-04-21 16:40:06         63.910         47.545
#
#    throttle_pct  max_steering_rate_deg_per_s  peak_fwd_x_g  peak_rear_x_g  \
# 0        47.438                      139.923         0.158          -0.36
# 1        70.517                      191.011         0.411          -0.46
#
#    peak_right_y_g  ...  peak_down_z_g  overspeed_count  hard_brake_count  \
# 0           0.230  ...         -0.045                0                 0
# 1           0.292  ...         -0.068                0                 3
#
#    swerving_count  handling_risk_score  event_code  distance_tr_km  \
# 0               0                 0.00        NONE           3.598
# 1               0                14.75    HARD_BRK          46.357
#
#   traffic_condition  weather_condition trip_duration_min
# ...

# %% [markdown]
# Note that the four columns representing acceleration in x, y, and z dimensions are signed. We can replace them with the absolute magnitude instead, since the column name itself already denotes the direction of the force. This also makes correlations easier to interpret later on.

# %%
cols = ['peak_fwd_x_g',
        'peak_rear_x_g',
        'peak_left_y_g',
        'peak_right_y_g',
        'peak_up_z_g',
        'peak_down_z_g'
]

for col in cols:
    telemetry[col] = telemetry[col].abs()

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(
    data=telemetry,
    x='max_speed_kmh',
    ax=ax[0]
)

sns.histplot(
    data=telemetry,
    x='max_speed_kmh',
    ax=ax[1]
)

plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of maximum recorded vehicle speeds exhibits a right-skewed shape centered around 50 km/h. While the vast majority of delivery drivers operate within a standard range of approximately 42-61 km/h, the boxplot reveals a high density of extreme outliers stretching from 90 km/h up to 140 km/h, indicating that a subset of vehicles heavily exceeds the standard driving behavior of the fleet. Prior examination of these extremes indicate that they are possibly valid. Moreover, since the data will be used for violation classification, we keep such data points to represent such genuine rare events (which improves model robustness).

# %%
fig, ax = plt.subplots(2,2, figsize=(13, 6))

cols = ['avg_speed_kmh', 'max_steering_rate_deg_per_s']

sns.boxplot(
    data=telemetry,
    x=cols[0],
    ax=ax[0,0],
)
sns.boxplot(
    data=telemetry,
    x=cols[1],
    ax=ax[0,1]
)

sns.histplot(
    data=telemetry,
    x=cols[0],
    ax=ax[1,0]
)
sns.histplot(
    data=telemetry,
    x=cols[1],
    ax=ax[1,1]
)


plt.tight_layout()
plt.show()

# %% [markdown]
# Next, we examine average speed and maximum steering rate per second. Most delivery drivers operate the vehicles with an average speed of around 20-60 km/h, implying adherence to speed limits and traffic rules. There also appears to be a small amount of observations where delivery vehicles travel way slower than 20km/h. This may be due to situations such as periods of heavy traffic jams, prompting drivers to slow down and frequently stop. The right tail also shows that only a few delivery vehicles achieved an average speed in the higher 80's. A likely reason for this is that such vehicles travelled using expressways and drove at the speed limit (which is around 80 km/h for trucks and buses). The boxplot also shows that there are observations at the far right of the distribution. These indicate that there are some drivers that frequently go over the speed limit in certain areas.
#
# As for maximum steering rate per second, the data appears to look normally distributed around 150 deg/s. Not much can be concluded from looking at these values alone to determine risky driving behavior. Trips with high steering rates can have no record of swerving, because such steering input can be made when performing parking maneuvers. The same can be said for relatively lower steering rates. At high speeds, even an input of 100 deg/s can be dangerous since the vehicle's speed amplifies lateral forces, increasing the chance of swerving/sliding.

# %%
fig, ax = plt.subplots(3, 2, figsize=(12, 7))

box_cols = [
    'peak_fwd_x_g',
    'peak_rear_x_g',
    'peak_left_y_g',
    'peak_right_y_g',
    'peak_up_z_g',
    'peak_down_z_g',
]

row_idx = 0
col_idx = 0

for col in box_cols:

    if col_idx > 1:
        row_idx += 1
        col_idx = 0

    sns.histplot(
        data=telemetry,
        x=col,
        ax=ax[row_idx, col_idx]
    )

    col_idx += 1

plt.tight_layout()
plt.subplots_adjust(hspace=0.5, wspace=0.2)
plt.show()

# %% [markdown]
# The distributions for longitudinal and lateral acceleration exhibit the same right skew. The observations are pulled slightly to the left, indicating that most drivers are smooth on the braking and steering. Of course, on the right tail, there are a few trips with g-forces approaching the highehr 0.7-0.8g's, which is quite high for vehicles such as delivery trucks/vans. These values may indicate aggressive handling (hard braking and steering) or accident avoidance (braking hard or steering away from obstacles such as jaywalking pedestrians, other vehicles, etc.).
#
# There is also a distinct peak in the data distribution for vertical g-force. A high count of deliveries with these close-to-zero values likely mean that the routes followed by most delivery vehicles have little to no hills or inclined roads. It could also mean that drivers are taking extra caution when driving on inclines, as most vertical acceleration values cluster around 0 to 0.15g, with maximums reaching up to 0.3g.

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))

sns.histplot(
    data=telemetry,
    x='distance_tr_km',
    ax=ax[0]
)

sns.histplot(
    data=telemetry,
    x='trip_duration_min',
    ax=ax[1]
)

plt.show()

# %% [markdown]
# Up next is distance travelled and trip duration. We can infer from this plot that most deliveries are made within the city, with some possibly being intercity as described by the tail stretching past 60 kilometers. The far right end of the tail shows some trips had destinations of over 100 kilometers, however. Since there is no geographic information specified, we would have to assume that these observations represent delivery trips made to distant cities or neighboring regions.
#
# Looking at trip duration, there is also a distinct peak at the far right tail. The sudden spike in frequency can indicate that these entries are erroneous or that the readings were capped. We check the range first:

# %%
telemetry['trip_duration_min'].describe()
# Out:
# count    67833.000000
# mean        50.439922
# std         63.510585
# min          3.000000
# 25%         12.300000
# 50%         26.933333
# 75%         60.966667
# max        360.000000
# Name: trip_duration_min, dtype: float64

# %% [markdown]
# Then we'll check exactly how many records:

# %%
# overall amount
telemetry.loc[telemetry['trip_duration_min'] == 360, :].shape[0]
# Out:
# 663

# %%
# also check if such trip duration values occur for trips below 60km
filter = telemetry.loc[
    (telemetry['trip_duration_min'] == 360) & (telemetry['distance_tr_km'] < telemetry['distance_tr_km'].quantile(0.95)),
    ['distance_tr_km', 'trip_duration_min']
]

filter.head()
# Out:
#       distance_tr_km  trip_duration_min
# 81            62.386              360.0
# 2111          44.255              360.0
# 3594          64.109              360.0
# 4394          64.879              360.0
# 4895          41.429              360.0

# %% [markdown]
# The likely cause is that the trip duration readings for these observations were somehow capped or the telemetry hardware must have malfunctioned. Regardless, we can exclude these observations as they only make up barely 1% of the dataset.

# %%
telemetry = telemetry.loc[telemetry['trip_duration_min'] < 360,:]

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# Rating labels can be added to the ratings table, where each rating is assignend to a specific bin. This allows raw rating values to be categorized.

# %%
ratings['rating_category'] = pd.cut(
    ratings['rating'],
    bins=[1.0, 2.5, 3.5, 4.2, 5.0],
    labels=['Poor','Fair','Good','Excellent']
)

# %% [markdown]
# We also create features for peak lateral and longitudinal accelerations, since both represent only one type of magnitude. This also reduces simplifies our correlations (and reduces clutter in the heatmap later on).

# %%
telemetry['peak_long_g'] = telemetry[['peak_fwd_x_g', 'peak_rear_x_g']].max(axis=1)
telemetry['peak_lat_g'] = telemetry[['peak_right_y_g','peak_left_y_g']].max(axis=1)

# %% [markdown]
# Finally, we create columns for the weekday and the time of day deliveries were made.

# %%
telemetry['delivery_dayofweek'] = telemetry['timestamp'].dt.day_name()
telemetry['time_of_day'] = pd.cut(
    telemetry['timestamp'].dt.hour,
    bins=[7, 11, 15, 20],
    labels=['Morning', 'Noon/Early Afternoon','Late Afternoon/Evening']
)

# %%
# checking the dataframe
telemetry.head(3)
# Out:
#        trip_id  driver_id           timestamp  max_speed_kmh  avg_speed_kmh  \
# 0  TRP-100-001  DRV100395 2026-05-19 13:05:21         27.382         20.275
# 1  TRP-100-002  DRV100381 2026-04-21 16:40:06         63.910         47.545
# 2  TRP-100-003  DRV100508 2026-03-07 09:03:45         47.191         34.784
#
#    throttle_pct  max_steering_rate_deg_per_s  peak_fwd_x_g  peak_rear_x_g  \
# 0        47.438                      139.923         0.158          0.360
# 1        70.517                      191.011         0.411          0.460
# 2        50.944                      183.156         0.484          0.394
#
#    peak_right_y_g  ...  handling_risk_score  event_code  distance_tr_km  \
# 0           0.230  ...                 0.00        NONE           3.598
# 1           0.292  ...                14.75    HARD_BRK          46.357
# 2           0.291  ...                 5.74       SWERV         119.956
#
# ...

# %% [markdown]
# ##### Correlations

# %% [markdown]
# We can then examine the correlations between numeric features. Since the ratings table contain a numeric value too (rating), we merge it together with the telemetry table.

# %%
merged = telemetry.merge(ratings, on=['trip_id','driver_id'])

telemetry_ratings_merge = merged[["rating", 
        "late_delivery_flag", 
        "overspeed_count", 
        "swerving_count",
        "hard_brake_count",
        "max_speed_kmh",
        "avg_speed_kmh",
        "handling_risk_score",
        "distance_tr_km",
        "max_steering_rate_deg_per_s",
        "peak_long_g",
        "peak_lat_g",
]]

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.heatmap(
    telemetry_ratings_merge.corr('spearman',numeric_only=True), 
    annot=True,
    ax=ax
)

plt.show()

# %% [markdown]
# We use Spearman's rank correlation to calculate the correlation coefficients, since most of the features have a skewed shape.
#
# At first glance, we notice a group of moderate to strong pairwise correlations at the lower right portion of the heatmap. These correlations are mostly telemetry data interactions which do not provide us with much information on driver behavior.
#
# Also notice `overspeed_count`, `swerving_count`, and `hard_brake_count` have moderate to strong correlations with `handling_risk_score`. We can infer which feature influences this score the most later on.
#
# Apart from this, the correlation between `rating` and `handling_risk_score` shows a moderate to strong correlation of about -0.6. Since `handling_risk_score` indicates how likely packages are to get damaged, we can assume that the more aggressive a driver is with their handling, the lower the customers' satisfaction will be due to package damage.
#
# There is also a moderate correlation between `rating` and `late_delivery_flag`, which implies that a late delivery usually gets lower ratings.

# %%
fig, ax = plt.subplots(1, 4, figsize=(17, 5))

data=telemetry_ratings_merge.sample(20000, random_state=42)

sns.stripplot(
    data=data,
    x='swerving_count',
    y='rating',
    jitter=True,
    alpha=0.25,
    ax=ax[0]
)

sns.stripplot(
    data=data,
    x='hard_brake_count',
    y='rating',
    jitter=True,
    alpha=0.25,
    ax=ax[1]
)


sns.stripplot(
    data=data,
    x='overspeed_count',
    y='rating',
    jitter=True,
    alpha=0.25,
    ax=ax[2]
)

sns.stripplot(
    data=data,
    x='late_delivery_flag',
    y='rating',
    jitter=True,
    alpha=0.25,
    ax=ax[3]
)


plt.tight_layout()
plt.show()

# %% [markdown]
# We use a jittered strip plot on the supposedly 'constituent' features of `handling_risk_score` and the `late_delivery_flag`, and compare each to `rating`. Notice the drop in ratings as swerving, hard brarking, and overspeed instances increase. The most significant looking drop occurs for `swerving_count` and the least for `overspeed_count`. This shows that vehicle swerves are the primary cause of compromised package integrity, resulting in lower ratings.

# %% [markdown]
# #### General Aggregates

# %%
fig, ax = plt.subplots(2, 2, figsize=(19, 9))

sns.countplot(
    data=telemetry.loc[telemetry['event_code'] != 'NONE',:],
    y='event_code',
    order=['HARD_BRK','SWERV','OVRSPD','MULTI'],
    ax=ax[0, 0]
)

sns.countplot(
    data=merged.loc[merged['late_delivery_flag'] == 1,:],
    x='traffic_condition',
    hue='weather_condition',
    ax=ax[0, 1]
)

sns.countplot(
    data=merged.assign(late_delivery_flag=merged['late_delivery_flag'].map({1:'Late',0:'On time'})),
    order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],
    x='delivery_dayofweek',
    hue='late_delivery_flag',
    ax=ax[1, 0]
)

sns.countplot(
    data=merged.assign(late_delivery_flag=merged['late_delivery_flag'].map({1:'Late',0:'On time'})),
    x='time_of_day',
    hue='late_delivery_flag',
    ax=ax[1, 1]
)

ax[0, 1].set_ylabel('late_deliveries')
plt.tight_layout()
plt.show()

# %% [markdown]
# The above plots describe miscellaneous details and general insights from the data.
#
# The upper left bar chart shows that hard braking (denoted by HARD_BRK) is the most frequent recorded event by telemetry hardware during trips. On top of that, there are around 8000 trips that have had multiple handling events logged, possibly indicating dangerous driving.
#
# The upper right chart shows late delivery volume under each traffic condition. Regardless of weather condition, it appears that most late deliveries occur during periods of moderate and heavy traffic. The remaining charts below show overall delivery volume for each day of the week and time of day. Most deliveries, regardless of on time or late arrival, appear to be of consistently high volume throughout the days of the week, indicating high operational throughput. Additionally, deliveries peak around the middle of the day.

# %% [markdown]
# # EXPORT

# %%
telemetry.head()
# Out:
#        trip_id  driver_id           timestamp  max_speed_kmh  avg_speed_kmh  \
# 0  TRP-100-001  DRV100395 2026-05-19 13:05:21         27.382         20.275
# 1  TRP-100-002  DRV100381 2026-04-21 16:40:06         63.910         47.545
# 2  TRP-100-003  DRV100508 2026-03-07 09:03:45         47.191         34.784
# 3  TRP-100-004  DRV100293 2026-05-17 11:24:03         36.977         25.289
# 4  TRP-100-005  DRV100076 2026-04-04 15:07:38         34.345         28.630
#
#    throttle_pct  max_steering_rate_deg_per_s  peak_fwd_x_g  peak_rear_x_g  \
# 0        47.438                      139.923         0.158          0.360
# 1        70.517                      191.011         0.411          0.460
# 2        50.944                      183.156         0.484          0.394
# 3        32.907                      140.210         0.300          0.376
# 4        19.886                      151.397         0.215          0.238
#
# ...

# %% [markdown]
# The features to be used for model training will be carefully determined in a future notebook, thus we do not exclude any of them for now.

# %%
telemetry_and_ratings = telemetry.merge(ratings, on=['trip_id','driver_id'])

# %%
telemetry_and_ratings.to_csv('../data/preprocessed/telemetry_ratings_preprocessed.csv')
